# %%
import numpy as np
import pandas as pd

import scanpy as sc
import scvelo as scv

import matplotlib.pyplot as plt
import seaborn as sns

import myutils

import random
import os

myutils.set_figure_params()
sc.settings.verbosity = 3

# %%
adata = sc.read_h5ad("./2.1.keratinocyte_final.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 60485 × 25998
#     obs: 'cell_id', 'sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_counts', 'condition', 'leiden', 'CellType', 'condition_final', 'leiden1.0', 'leiden0.5', 'CellType2'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'CellType2_colors', 'CellType_colors', 'batch_colors', 'condition_colors', 'hvg', 'leiden', 'leiden0.5', 'leiden1.0', 'leiden1.0_colors', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
import loompy as lp

# %%
adata_raw = sc.read_h5ad("../1_preprocess_integration/1.scRNA_merge_raw.h5ad") [adata.obs_names]
adata_raw.obs = adata.obs
adata_raw
# Out:
# AnnData object with n_obs × n_vars = 60485 × 31129
#     obs: 'cell_id', 'sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_counts', 'condition', 'leiden', 'CellType', 'condition_final', 'leiden1.0', 'leiden0.5', 'CellType2'

# %%
row_attrs = {"Gene": np.array(adata_raw.var_names),};
col_attrs = {"CellID": np.array(adata_raw.obs_names)};
lp.create("2.2.scenic_input.loom",adata_raw.X.transpose(),row_attrs,col_attrs)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 3
#       1 row_attrs = {"Gene": np.array(adata_raw.var_names),};
#       2 col_attrs = {"CellID": np.array(adata_raw.obs_names)};
# ----> 3 lp.create("2.2.scenic_input.loom",adata_raw.X.transpose(),row_attrs,col_attrs)
#
# File ~\.conda\envs\scanpy\lib\site-packages\loompy\loompy.py:1078, in create(filename, layers, row_attrs, col_attrs, file_attrs)
#    1076 try:
#    1077 	with new(filename, file_attrs=file_attrs) as ds:
# -> 1078 		ds.layer[""] = layers[""]
#    1079 		for key, vals in layers.items():
#    1080 			if key == "":
#
# File ~\.conda\envs\scanpy\lib\site-packages\loompy\layer_manager.py:90, in LayerManager.__setitem__(self, name, val)
#      89 def __setitem__(self, name: str, val: np.ndarray) -> None:
# ---> 90 	return self.__setattr__(name, val)
#
# ...
