# %% [markdown]
# # 3.2.Run

# %%
cpdb_file_path = '../../Data/v5.0.0/cellphonedb.zip'
meta_file_path = './5.1.CellPhoneDB/metadata_by_condition.tsv'
counts_file_path = './5.1.CellPhoneDB/normalised_log_counts_by_condition.h5ad'
out_path = './5.1.CellPhoneDB/results/method2_withScore'

# %%
from cellphonedb.src.core.methods import cpdb_statistical_analysis_method

cpdb_results = cpdb_statistical_analysis_method.call(
    cpdb_file_path = cpdb_file_path,                 # mandatory: CellphoneDB database zip file.
    meta_file_path = meta_file_path,                 # mandatory: tsv file defining barcodes to cell label.
    counts_file_path = counts_file_path,             # mandatory: normalized count matrix - a path to the counts file, or an in-memory AnnData object
    counts_data = 'hgnc_symbol',                     # defines the gene annotation in counts matrix.
    score_interactions = True,                       # optional: whether to score interactions or not. 
    iterations = 1000,                               # denotes the number of shufflings performed in the analysis.
    threshold = 0.1,                                 # defines the min % of cells expressing a gene for this to be employed in the analysis.
    threads = 12,                                     # number of threads to use in the analysis.
    debug_seed = 42,                                 # debug randome seed. To disable >=0.
    result_precision = 3,                            # Sets the rounding for the mean values in significan_means.
    pvalue = 0.05,                                   # P-value threshold to employ for significance.
    subsampling = False,                             # To enable subsampling the data (geometri sketching).
    subsampling_log = False,                         # (mandatory) enable subsampling log1p for non log-transformed data inputs.
    subsampling_num_pc = 100,                        # Number of componets to subsample via geometric skectching (dafault: 100).
    separator = '|',                                 # Sets the string to employ to separate cells in the results dataframes "cellA|CellB".
    debug = False,                                   # Saves all intermediate tables employed during the analysis in pkl format.
    output_path = out_path,                          # Path to save results.
    output_suffix = None                             # Replaces the timestamp in the output files by a user defined string in the  (default: None).
    )
# Out:
# Reading user files...
# The following user files were loaded successfully:
# ./10.4.CellPhoneDB/normalised_log_counts_by_condition.h5ad
# ./10.4.CellPhoneDB/metadata_by_condition.tsv
# [ ][CORE][21/07/25-15:50:28][INFO] [Cluster Statistical Analysis] Threshold:0.1 Iterations:1000 Debug-seed:42 Threads:12 Precision:3
# [ ][CORE][21/07/25-15:50:28][WARNING] Debug random seed enabled. Set to 42
# [ ][CORE][21/07/25-15:50:44][INFO] Running Real Analysis
# [ ][CORE][21/07/25-15:50:45][INFO] Running Statistical Analysis
# ...
# 100%|██████████| 1000/1000 [26:41<00:00,  1.60s/it]
# [ ][CORE][21/07/25-16:17:28][INFO] Building Pvalues result
# [ ][CORE][21/07/25-16:17:30][INFO] Building results
# [ ][CORE][21/07/25-16:17:30][INFO] Scoring interactions: Filtering genes per cell type..
# ...
# 100%|██████████| 34/34 [00:03<00:00,  9.92it/s]
# [ ][CORE][21/07/25-16:17:34][INFO] Scoring interactions: Calculating mean expression of each gene per group/cell type..
# ...

# %%
list(cpdb_results.keys())
# Out:
# ['deconvoluted',
#  'deconvoluted_percents',
#  'means',
#  'pvalues',
#  'significant_means',
#  'CellSign_active_interactions',
#  'CellSign_active_interactions_deconvoluted',
#  'interaction_scores']
